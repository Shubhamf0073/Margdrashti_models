# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install scikit-learn pandas pillow tqdm
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
from google.colab import files
import zipfile

uploaded = files.upload()

# !unzip -q colab_upload.zip
# !ls -la
# Out:
#      <input type="file" id="files-c17e46aa-c41f-49f7-b0af-425d52fd0f7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c17e46aa-c41f-49f7-b0af-425d52fd0f7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !head -5 video_analysis_script/data/splits_224/train.csv
# Out:
# tile_path,label_id,label_name,video_id,frame_idx,x,y,tile
# tiles/dirty_highway_dirty_highway10__f000024__x0448_y0224.jpg,2.0,ignore,dirty_highway_dirty_highway10,24,448,224,224
# tiles/dirty_sector_dirty_sector1__f001668__x0224_y0224.jpg,1.0,unclean,dirty_sector_dirty_sector1,1668,224,224,224
# tiles/dirty_sector_dirty_sector4__f001320__x0448_y0224.jpg,2.0,ignore,dirty_sector_dirty_sector4,1320,448,224,224
# tiles/dirty_highway_dirty_highway10__f000219__x0448_y0224.jpg,1.0,unclean,dirty_highway_dirty_highway10,219,448,224,224

# %%
# !python train_efficientnet.py \
    --train_csv /content/video_analysis_script/data/splits_224/train.csv \
    --val_csv /content/video_analysis_script/data/splits_224/val.csv \
    --data_root /content \
    --out_dir models/efficientnet_224 \
    --stage1_epochs 10 \
    --stage2_epochs 10 \
    --batch 128 \
    --drop_ignore
# Out:
# ...
# LOADING DATASETS
# ...
#
# Dataset info:
#   Training:   3,606 samples
#   Validation: 586 samples
#   Classes:    ['clean', 'unclean']
#
# Class distribution (training):
#   clean     :  1960 ( 54.4%)
#   unclean   :  1646 ( 45.6%)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
#
# ...
# INITIALIZING MODEL
# ...
# Device: cpu
# Architecture: EfficientNet-B0
# Parameters:   4,010,110
# Class weights: [0.91292286 1.0870771 ]
#
# ...
# STAGE 1: TRAINING WITH FROZEN BACKBONE
# ...
# Epochs: 10
# Learning rate: 0.001
# Trainable parameters: 2,562
# ...

# %%
# !head -3 /content/video_analysis_script/data/splits_224/train.csv
# Out:
# tile_path,label_id,label_name,video_id,frame_idx,x,y,tile
# tiles/dirty_highway_dirty_highway10__f000024__x0448_y0224.jpg,2.0,ignore,dirty_highway_dirty_highway10,24,448,224,224
# tiles/dirty_sector_dirty_sector1__f001668__x0224_y0224.jpg,1.0,unclean,dirty_sector_dirty_sector1,1668,224,224,224
